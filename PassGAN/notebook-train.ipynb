# %% [markdown]
# # Training PassGAN

# %% [markdown]
# This Jupyter notebook is mainly for debugging, has same functionality to "train.py". However, the parameters are configured small.

# %% [markdown]
# ## Dependencies

# %%
import os, sys
sys.path.append(os.getcwd())

import time
import pickle
import numpy as np
import tensorflow as tf

import utils
import tflib as lib
import tflib.ops.linear
import tflib.ops.con1
import tflib.plot
import mod1
# Out:
# WARNING:tensorflow:From c:\Users\aswan\project\project\sample\PassGAN\tflib\ops\l2.py:3: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# TensorFlow virsion
print(tf.__version__)
# Out:
# 2.16.1

# %% [markdown]
# ## Parameters

# %% [markdown]
# To simplify migration process between Jupyter Notebook and .py format, we created virtual ArgumentParser class.

# %%
# Class to virtualize ArgumentParser
class VirtualArgparse:
    
    # Path to dataset
    training_data = "data/text.txt"
    
    # Name of directory to output
    output_dir = "pretrained"
    
    save_every = 10   #5000
    iters = 100   #200000
    batch_size = 64
    seq_length = 10
    layer_dim = 128
    critic_iters = 10
    lamb = 10

# %%
# Virtualize ArgumentParser instance
args = VirtualArgparse

# %% [markdown]
# ## Creating Directories

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

if not os.path.isdir(os.path.join(args.output_dir, 'checkpoints')):
    os.makedirs(os.path.join(args.output_dir, 'checkpoints'))

if not os.path.isdir(os.path.join(args.output_dir, 'samples')):
    os.makedirs(os.path.join(args.output_dir, 'samples'))

# %% [markdown]
# ## Importing Dataset

# %%
lines, charmap, inv_charmap = utils.load_dataset(
    path=args.training_data,
    max_length=args.seq_length)
# Out:
# loaded 120 lines in dataset

# %% [markdown]
# ## Creating Dictionary

# %%
# Pickle to avoid encoding errors with json
with open(os.path.join(args.output_dir, 'charmap.pickle'), 'wb') as f:
    pickle.dump(charmap, f)

with open(os.path.join(args.output_dir, 'charmap_inv.pickle'), 'wb') as f:
    pickle.dump(inv_charmap, f)
print(charmap)
print("Number of unique characters in dataset: {}".format(len(charmap)))
# Out:
# {'unk': 0, '`': 1, 'f': 2, 'd': 3, 'g': 4, 's': 5, 'h': 6, '4': 7, 'e': 8, '5': 9, 'l': 10, 'y': 11, '.': 12, 'i': 13, 'o': 14, '3': 15}
# Number of unique characters in dataset: 16

# %% [markdown]
# ## Modeling Generator

# %%
real_inputs_discrete = tf.random.uniform(shape=[args.batch_size, args.seq_length], minval=0, maxval=len(charmap), dtype=tf.int32)
real_inputs = tf.one_hot(real_inputs_discrete, 96)

# %%
print(real_inputs_discrete)
print(real_inputs)
# Out:
# Tensor("random_uniform:0", shape=(64, 10), dtype=int32)
# Tensor("one_hot:0", shape=(64, 10, 96), dtype=float32)

# %%
fake_inputs = mod1.Generator(args.batch_size, args.seq_length, args.layer_dim, len(charmap))
# Out:
# Linear layer: Generator.Input, Input dim: 128, Output dim: 1280
# Weight values shape: (128, 1280), dtype: float32
# Creating new parameter: Generator.Input.W, Value shape: (128, 1280), dtype: float32
# Created weight: <tf.Variable 'Generator.Input/Generator.Input.W:0' shape=(128, 1280) dtype=float32_ref>
# Creating new parameter: Generator.Input.b, Value shape: (1280,), dtype: float32
# Result shape: (64, 1280), dtype: <dtype: 'float32'>

# %%
fake_inputs_discrete = tf.argmax(fake_inputs, fake_inputs.get_shape().ndims-1)

# %% [markdown]
# ## Modeling Discriminator

# %%
disc_real = mod1.Discriminator(real_inputs, args.seq_length, args.layer_dim, len(charmap))
disc_fake = mod1.Discriminator(fake_inputs, args.seq_length, args.layer_dim, len(charmap))

disc_cost = tf.reduce_mean(disc_fake) - tf.reduce_mean(disc_real)
gen_cost = -tf.reduce_mean(disc_fake)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 disc_real = mod1.Discriminator(real_inputs, args.seq_length, args.layer_dim, len(charmap))
#       2 disc_fake = mod1.Discriminator(fake_inputs, args.seq_length, args.layer_dim, len(charmap))
#       4 disc_cost = tf.reduce_mean(disc_fake) - tf.reduce_mean(disc_real)
#
# File c:\Users\aswan\project\project\sample\PassGAN\mod1.py:35, in Discriminator(inputs, seq_len, layer_dim, input_dim)
#      33 def Discriminator(inputs, seq_len, layer_dim, input_dim):
#      34     output = inputs
# ---> 35     output = lib.ops.con1.Conv1D('Discriminator.Input', input_dim, layer_dim, 1, output)
#      36     output = ResBlock('Discriminator.1', output, layer_dim)
#      37     output = ResBlock('Discriminator.2', output, layer_dim)
#
# File c:\Users\aswan\project\project\sample\PassGAN\tflib\ops\con1.py:88, in Conv1D(name, input_dim, output_dim, filter_size, inputs, he_init, mask_type, stride, weightnorm, biases, gain)
#      85     with tf.name_scope('filter_mask'):
#      86         filters = filters * mask
# ---> 88 result = tf.nn.conv1d(
#      89     input=inputs,
#      90     filters=filters,
#      91     stride=stride,
#      92     padding='SAME'
#      93 )
#      95 if biases:
#      96     _biases = lib.param(
#      97         name+'.Biases',
#      98         np.zeros([output_dim], dtype='float32')
#      99     )
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\framework\ops.py:1037, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1034   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1035 except errors.InvalidArgumentError as e:
#    1036   # Convert to ValueError for backwards compatibility.
# -> 1037   raise ValueError(e.message)
#    1039 # Record the current Python stack trace as the creating stacktrace of this
#    1040 # TF_Operation.
#    1041 if extract_traceback:
#
# ValueError: Depth of output (128) is not a multiple of the number of groups (6) for '{{node Discriminator.Input/conv1d}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](Discriminator.Input/conv1d/ExpandDims, Discriminator.Input/conv1d/ExpandDims_1)' with input shapes: [64,1,10,96], [1,1,16,128].

# %%
# WGAN lipschitz-penalty
alpha = tf.random.uniform(
    shape=[args.batch_size, 1, 1],
    minval=0.0,
    maxval=1.0
)

differences = fake_inputs - real_inputs
interpolates = real_inputs + (alpha * differences)
gradients = tf.gradients(mod1.Discriminator(interpolates, args.seq_length, args.layer_dim, len(charmap)), [interpolates])[0]
slopes = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1, 2]))
gradient_penalty = tf.reduce_mean((slopes - 1.0) ** 2)
disc_cost += args.lamb * gradient_penalty

gen_params = lib.params_with_name('Generator')
disc_params = lib.params_with_name('Discriminator')


# ... rest of your code ...

# gen_train_op = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.9).minimize(gen_cost, var_list=gen_params)
# disc_train_op = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.9).minimize(disc_cost, var_list=disc_params)
gen_train_op = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.9)
disc_train_op = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.9)
gen_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=1e-4, beta1=0.5, beta2=0.9)
disc_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=1e-4, beta1=0.5, beta2=0.9)
# Out:
# Linear layer: Discriminator.Output, Input dim: 1280, Output dim: 1
# Weight values shape: (1280, 1), dtype: float32
# Created weight: <tf.Variable 'Discriminator.Output/Discriminator.Output.W:0' shape=(1280, 1) dtype=float32_ref>
# Result shape: (64, 1), dtype: <dtype: 'float32'>

# %%
# Dataset iterator
def inf_train_gen():
    while True:
        np.random.shuffle(lines)
        for i in range(0, len(lines)-args.batch_size+1, args.batch_size):
            yield np.array(
                [[charmap[c] for c in l] for l in lines[i:i+args.batch_size]],
                dtype='int32'
            )

# %%
# During training we monitor JS divergence between the true & generated ngram
# distributions for n=1,2,3,4. To get an idea of the optimal values, we
# evaluate these statistics on a held-out set first.
true_char_ngram_lms = [utils.NgramLanguageModel(i+1, lines[10*args.batch_size:], tokenize=False) for i in range(4)]
validation_char_ngram_lms = [utils.NgramLanguageModel(i+1, lines[:10*args.batch_size], tokenize=False) for i in range(4)]
for i in range(4):
    print("validation set JSD for n={}: {}".format(i+1, true_char_ngram_lms[i].js_with(validation_char_ngram_lms[i])))
true_char_ngram_lms = [utils.NgramLanguageModel(i+1, lines, tokenize=False) for i in range(4)]
# Out:
# validation set JSD for n=1: 0.5
# validation set JSD for n=2: 0.49999999999999994
# validation set JSD for n=3: 0.5000000000000001
# validation set JSD for n=4: 0.5000000000000001

# %% [markdown]
# ## TensorFlow Session

# %%
import tensorflow as tf
import numpy as np
import time
import os

# Assuming args, fake_inputs, real_inputs, mod1, charmap, inv_charmap, inf_train_gen, compute_gen_cost, compute_disc_cost, utils, true_char_ngram_lms, and lib are already defined

# Define WGAN lipschitz-penalty
alpha = tf.random.uniform(shape=[args.batch_size, 1, 1], minval=0.0, maxval=1.0)
differences = fake_inputs - real_inputs
interpolates = real_inputs + (alpha * differences)
with tf.GradientTape() as tape:
    tape.watch(interpolates)
    d_interpolates = mod1.Discriminator(interpolates, args.seq_length, args.layer_dim, len(charmap))
gradients = tape.gradient(d_interpolates, [interpolates])[0]
slopes = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1, 2]))
gradient_penalty = tf.reduce_mean((slopes - 1.0) ** 2)
disc_cost += args.lamb * gradient_penalty

# Assume these functions return a cost to minimize


# Get parameters for generator and discriminator
gen_params = lib.params_with_name('Generator')
disc_params = lib.params_with_name('Discriminator')

# Define optimizers
gen_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=1e-4, beta1=0.5, beta2=0.9)
disc_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=1e-4, beta1=0.5, beta2=0.9)

# Define training operations
gen_train_op = gen_optimizer.minimize(gen_cost, var_list=gen_params)
disc_train_op = disc_optimizer.minimize(disc_cost, var_list=disc_params)

# Create the TensorFlow session
with tf.compat.v1.Session() as session:
    
    # Time stamp
    localtime = time.asctime(time.localtime(time.time()))
    print("Starting TensorFlow session...")
    print("Local current time :", localtime)
    
    # Initialize variables
    session.run(tf.compat.v1.global_variables_initializer())

    def generate_samples():
        samples = session.run(fake_inputs)
        samples = np.argmax(samples, axis=2)
        decoded_samples = []
        for i in range(len(samples)):
            decoded = []
            for j in range(len(samples[i])):
                decoded.append(inv_charmap[samples[i][j]])
            decoded_samples.append(tuple(decoded))
        return decoded_samples

    gen = inf_train_gen()

    for iteration in range(args.iters + 1):
        start_time = time.time()

        # Train Generator
        if iteration > 0:
            session.run(gen_train_op)

        # Train Discriminator
        for i in range(args.critic_iters):
            _data = next(gen)

            # Debugging steps
            print(f"Iteration: {iteration}, Critic Iteration: {i}")
            print(f"_data shape: {_data.shape}")
            print(f"real_inputs_discrete expected shape: {real_inputs_discrete.shape}")

            try:
                _disc_cost, _ = session.run(
                    [disc_cost, disc_train_op],
                    feed_dict={real_inputs_discrete: _data}
                )
            except Exception as e:
                print(f"Error during session.run: {e}")
                break

        lib.plot.output_dir = args.output_dir
        lib.plot.plot('time', time.time() - start_time)
        lib.plot.plot('train disc cost', _disc_cost)

        # Output to text file after every 100 samples
        if iteration % 100 == 0 and iteration > 0:
            samples = []
            for _ in range(10):
                samples.extend(generate_samples())

            for i in range(4):
                lm = utils.NgramLanguageModel(i+1, samples, tokenize=False)
                lib.plot.plot(f'js{i+1}', lm.js_with(true_char_ngram_lms[i]))

            os.makedirs(os.path.join(args.output_dir, 'samples'), exist_ok=True)
            with open(os.path.join(args.output_dir, 'samples', f'samples_{iteration}.txt'), 'w') as f:
                for s in samples:
                    s = "".join(s)
                    f.write(s + "\n")

        if iteration % args.save_every == 0 and iteration > 0:
            os.makedirs(os.path.join(args.output_dir, 'checkpoints'), exist_ok=True)
            model_saver = tf.compat.v1.train.Saver()
            model_saver.save(session, os.path.join(args.output_dir, 'checkpoints', f'checkpoint_{iteration}.ckpt'))
            print(f"{iteration} / {args.iters} ({iteration / args.iters * 100.0:.2f}%)")

        if iteration == args.iters:
            print("...Training done.")

        # Uncomment the following lines if you have the lib.plot.flush() and lib.plot.tick() functions available
        # if iteration % 100 == 0:
        #     lib.plot.flush()

        # lib.plot.tick()

# Time stamp
localtime = time.asctime(time.localtime(time.time()))
print("Ending TensorFlow session.")
print("Local current time :", localtime)
# Out:
# Linear layer: Discriminator.Output, Input dim: 1280, Output dim: 1
# Weight values shape: (1280, 1), dtype: float32
# Created weight: <tf.Variable 'Discriminator.Output/Discriminator.Output.W:0' shape=(1280, 1) dtype=float32_ref>
# Result shape: (64, 1), dtype: <dtype: 'float32'>
# Starting TensorFlow session...
# Local current time : Tue May 28 19:08:54 2024
# Iteration: 0, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 0, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 1, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 2, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 3, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 4, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 5, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 6, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 7, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 8, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 9, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 10, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 10 / 100 (10.00%)
# Iteration: 11, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 11, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 12, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 13, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 14, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 15, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 16, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 17, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 18, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 19, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 20, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 20 / 100 (20.00%)
# Iteration: 21, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 21, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 22, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 23, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 24, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 25, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 26, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 27, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 28, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 29, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 30, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 30 / 100 (30.00%)
# Iteration: 31, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 31, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 32, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 33, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 34, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 35, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 36, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 37, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 38, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 39, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 40, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 40 / 100 (40.00%)
# Iteration: 41, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 41, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 42, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 43, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 44, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 45, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 46, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 46, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 46, Critic Iteration: 2
# _data shape: (64, 10)
# ...
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 85, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 85, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 85, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 86, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 87, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 88, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 89, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 90, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 90 / 100 (90.00%)
# Iteration: 91, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 91, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 92, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 93, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 94, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 95, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 96, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 97, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 98, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 99, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 0
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 1
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 2
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 3
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 4
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 5
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 6
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 7
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 8
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# Iteration: 100, Critic Iteration: 9
# _data shape: (64, 10)
# real_inputs_discrete expected shape: (64, 10)
# 100 / 100 (100.00%)
# ...Training done.
# Ending TensorFlow session.
# Local current time : Tue May 28 19:13:18 2024

# %%
with tf.compat.v1.Session() as session:

    # Time stamp
    localtime = time.asctime( time.localtime(time.time()) )
    print("Starting TensorFlow session...")
    print("Local current time :", localtime)
    
    # Start TensorFlow session...
    session.run(tf.compat.v1.global_variables_initializer())

    def generate_samples():
        samples = session.run(fake_inputs)
        samples = np.argmax(samples, axis=2)
        decoded_samples = []
        for i in range(len(samples)):
            decoded = []
            for j in range(len(samples[i])):
                decoded.append(inv_charmap[samples[i][j]])
            decoded_samples.append(tuple(decoded))
        return decoded_samples

    gen = inf_train_gen()
    for iteration in range(args.iters + 1):
        start_time = time.time()

        # Train Generator
        if iteration > 0:
            print('gen_train_op')
            _ = session.run(gen_train_op)

        # Train Discriminator
        for i in range(args.critic_iters):
            _data = next(gen)
            _disc_cost, _ = session.run([disc_cost, disc_train_op],feed_dict={real_inputs_discrete:_data})
            

        lib.plot.output_dir = args.output_dir
        lib.plot.plot('time', time.time() - start_time)
        lib.plot.plot('train disc cost', _disc_cost)

        # Output to text file after every 100 samples
        if iteration % 100 == 0 and iteration > 0:

            samples = []
            for i in range(10):
                samples.extend(generate_samples())

            for i in range(4):
                lm = utils.NgramLanguageModel(i+1, samples, tokenize=False)
                lib.plot.plot('js{}'.format(i+1), lm.js_with(true_char_ngram_lms[i]))

            with open(os.path.join(args.output_dir, 'samples', 'samples_{}.txt').format(iteration), 'w') as f:
                for s in samples:
                    s = "".join(s)
                    f.write(s + "\n")

        if iteration % args.save_every == 0 and iteration > 0:
            model_saver = tf.train.Saver()
            model_saver.save(session, os.path.join(args.output_dir, 'checkpoints', 'checkpoint_{}.ckpt').format(iteration))
            print("{} / {} ({}%)".format(iteration, args.iters, iteration/args.iters*100.0 ))

        if iteration == args.iters:
            print("...Training done.")
        
        #if iteration % 100 == 0:
            #lib.plot.flush()

        #lib.plot.tick()
        
# Time stamp
localtime = time.asctime( time.localtime(time.time()) )
print("Ending TensorFlow session.")
print("Local current time :", localtime)
# Out:
# Starting TensorFlow session...
# Local current time : Tue May 28 19:06:58 2024
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:308, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     307 try:
# --> 308   self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     309       fetch, allow_tensor=True, allow_operation=True))
#     310 except TypeError as e:
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\framework\ops.py:2885, in Graph.as_graph_element(self, obj, allow_tensor, allow_operation)
#    2884 with self._lock:
# -> 2885   return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\framework\ops.py:2983, in Graph._as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    2981 else:
#    2982   # We give up!
# -> 2983   raise TypeError("Can not convert a %s into a %s." %
#    2984                   (type(obj).__name__, types_str))
#
# TypeError: Can not convert a Adam into a Tensor or Operation.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 34
#      32 for i in range(args.critic_iters):
#      33     _data = next(gen)
# ---> 34     _disc_cost, _ = session.run([disc_cost, disc_train_op],feed_dict={real_inputs_discrete:_data})
#      37 lib.plot.output_dir = args.output_dir
#      38 lib.plot.plot('time', time.time() - start_time)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:972, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     969 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     971 try:
# --> 972   result = self._run(None, fetches, feed_dict, options_ptr,
#     973                      run_metadata_ptr)
#     974   if run_metadata:
#     975     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:1200, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1197       feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1199 # Create a fetch handler to take care of the structure of fetches.
# -> 1200 fetch_handler = _FetchHandler(
#    1201     self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1203 # Run request and get response.
#    1204 # We need to keep the returned movers alive for the following _do_run().
#    1205 # These movers are no longer needed when _do_run() completes, and
#    1206 # are deleted when `movers` goes out of scope when this _run() ends.
#    1207 # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1208 # of a handle from a different device as an error.
#    1209 _ = self._update_with_movers(feed_dict_tensor, feed_map)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:489, in _FetchHandler.__init__(self, graph, fetches, feeds, feed_handles)
#     477 """Creates a fetch handler.
#     478
#     479 Args:
#    (...)
#     486     direct feeds.
#     487 """
#     488 with graph.as_default():
# --> 489   self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     490 self._fetches = []
#     491 self._targets = []
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:270, in _FetchMapper.for_fetch(fetch)
#     266   raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     267                   f'"{type(fetch).__name__}". Cannot be None')
#     268 elif isinstance(fetch, (list, tuple)):
#     269   # NOTE(touts): This is also the code path for namedtuples.
# --> 270   return _ListFetchMapper(fetch)
#     271 elif isinstance(fetch, collections_abc.Mapping):
#     272   return _DictFetchMapper(fetch)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:382, in _ListFetchMapper.__init__(self, fetches)
#     380 else:
#     381   self._fetch_type = type(fetches)
# --> 382 self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     383 self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:382, in <listcomp>(.0)
#     380 else:
#     381   self._fetch_type = type(fetches)
# --> 382 self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     383 self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:280, in _FetchMapper.for_fetch(fetch)
#     278     if isinstance(fetch, tensor_type):
#     279       fetches, contraction_fn = fetch_fn(fetch)
# --> 280       return _ElementFetchMapper(fetches, contraction_fn)
#     281 # Did not find anything.
#     282 raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     283                 f'"{type(fetch).__name__}"')
#
# File c:\Users\aswan\project\project\env\Lib\site-packages\tensorflow\python\client\session.py:311, in _ElementFetchMapper.__init__(self, fetches, contraction_fn)
#     308   self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     309       fetch, allow_tensor=True, allow_operation=True))
#     310 except TypeError as e:
# --> 311   raise TypeError(f'Argument `fetch` = {fetch} has invalid type '
#     312                   f'"{type(fetch).__name__}" must be a string or Tensor. '
#     313                   f'({str(e)})')
#     314 except ValueError as e:
#     315   raise ValueError(f'Argument `fetch` = {fetch} cannot be interpreted as '
#     316                    f'a Tensor. ({str(e)})')
#
# TypeError: Argument `fetch` = <keras.src.optimizers.adam.Adam object at 0x000001C20EA8E9D0> has invalid type "Adam" must be a string or Tensor. (Can not convert a Adam into a Tensor or Operation.)
